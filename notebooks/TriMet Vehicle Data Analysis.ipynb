# %% [markdown]
# # TriMet Vehicle Delays
#
# ### A look into vehicle delays in TriMet's rail system.
# <br>
# ***Kenneth Liao***
# <br>
# ***6/12/2018***

# %% [markdown]
# Rail vehicle delays are investigated over a 6 month period from January 1st, 2017 through June 30th, 2017.
#
# Problem Statement:
#     1. Which routes have the most delays?
#     2. Which routes have the longest delays?
#     3. Which stops have the longest delays?

# %%
# Import libraries and set default pyplot figure size to 10,10
import os
import pandas as pd
import numpy as np
import pylab
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from config import credentials

# Enable offline plotting
plotly.offline.init_notebook_mode(connected=True)

# Set plotly & mapbox credentials
plotly.tools.set_credentials_file(username=credentials['plotly_user'], 
                                  api_key=credentials['plotly_api_key'])
mapbox_access_token = credentials['mapbox_token']
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Change path to folder containing data
path = 'C:/Users/Kenny/projects/pds/trimet/data/trimet-rail'
os.chdir(path)

# %%
# Import the 1-month rail files and append them all into the same table
rail = pd.read_csv('rail-jan.csv')
rail = rail.append(pd.read_csv('rail-feb.csv'))
rail = rail.append(pd.read_csv('rail-mar.csv'))
rail = rail.append(pd.read_csv('rail-apr.csv'))
rail = rail.append(pd.read_csv('rail-may.csv'))
rail = rail.append(pd.read_csv('rail-jun.csv'))

rail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5461424 entries, 0 to 962225
# Data columns (total 18 columns):
# bearing                       int64
# blockID                       int64
# delay                         int64
# direction                     int64
# timestamp                     object
# garage                        object
# lastLocID                     int64
# lastStopSeq                   int64
# messageCode                   int64
# nextLocID                     int64
# nextStopSeq                   int64
# routeNumber                   int64
# signMessageLong               object
# tripID                        int64
# type                          object
# vehicle_id                    int64
# vehicle_location_longitude    float64
# vehicle_location_latitude     float64
# dtypes: float64(2), int64(12), object(4)
# memory usage: 791.7+ MB

# %%
rail.head()
# Out:
#    bearing  blockID  delay  direction            timestamp garage  lastLocID  \
# 0       42     9043   -138          0  2017-01-01 00:05:35   ELMO      10572
# 1      270     9043   -107          0  2017-01-01 00:07:26   ELMO      10574
# 2      299     9043   -138          0  2017-01-01 00:10:39   ELMO      10576
# 3        1     9043   -136          0  2017-01-01 00:04:51   ELMO      11616
# 4       42     9043   -138          0  2017-01-01 00:05:35   ELMO      10572
#
#    lastStopSeq  messageCode  nextLocID  nextStopSeq  routeNumber  \
# 0           23          927      10574           24           90
# 1           24          927      10576           25           90
# 2           25          927      10579           26           90
# 3           22          927      10572           23           90
# 4           23          927      10574           24           90
#
#             signMessageLong   tripID  type  vehicle_id  \
# 0  MAX  Red Line to Airport  6997146  rail         416
# 1  MAX  Red Line to Airport  6997146  rail         416
# 2  MAX  Red Line to Airport  6997146  rail         416
# 3  MAX  Red Line to Airport  6997146  rail         416
# 4  MAX  Red Line to Airport  6997146  rail         417
#
#    vehicle_location_longitude  vehicle_location_latitude
# 0                 -122.563200                  45.560901
# 1                 -122.561480                  45.572588
# 2                 -122.571721                  45.580453
# 3                 -122.567106                  45.556137
# 4                 -122.563200                  45.560901

# %% [markdown]
# ## Data Munging

# %%
# Convert timestamp to local datetime
rail['timestamp'] = pd.to_datetime(rail['timestamp'])
rail['timestamp'] = rail['timestamp'].dt.tz_localize('UTC').dt.tz_convert('America/Los_Angeles').dt.tz_localize(None)
rail['hour'] = rail['timestamp'].dt.hour
rail.head()
# Out:
#    bearing  blockID  delay  direction           timestamp garage  lastLocID  \
# 0       42     9043   -138          0 2016-12-31 16:05:35   ELMO      10572
# 1      270     9043   -107          0 2016-12-31 16:07:26   ELMO      10574
# 2      299     9043   -138          0 2016-12-31 16:10:39   ELMO      10576
# 3        1     9043   -136          0 2016-12-31 16:04:51   ELMO      11616
# 4       42     9043   -138          0 2016-12-31 16:05:35   ELMO      10572
#
#    lastStopSeq  messageCode  nextLocID  nextStopSeq  routeNumber  \
# 0           23          927      10574           24           90
# 1           24          927      10576           25           90
# 2           25          927      10579           26           90
# 3           22          927      10572           23           90
# 4           23          927      10574           24           90
#
#             signMessageLong   tripID  type  vehicle_id  \
# 0  MAX  Red Line to Airport  6997146  rail         416
# 1  MAX  Red Line to Airport  6997146  rail         416
# 2  MAX  Red Line to Airport  6997146  rail         416
# 3  MAX  Red Line to Airport  6997146  rail         416
# 4  MAX  Red Line to Airport  6997146  rail         417
#
#    vehicle_location_longitude  vehicle_location_latitude  hour
# 0                 -122.563200                  45.560901    16
# 1                 -122.561480                  45.572588    16
# 2                 -122.571721                  45.580453    16
# 3                 -122.567106                  45.556137    16
# 4                 -122.563200                  45.560901    16

# %%
# Use a dictionary to define line colors
message_dict = {}
for message in rail['signMessageLong'].unique():
    if 'Red' in message:
        message_dict[str(message)] = 'Red'
    elif 'Blue' in message:
        message_dict[str(message)] = 'Blue'
    elif 'Green' in message:
        message_dict[str(message)] = 'Green'
    elif 'Orange' in message:
        message_dict[str(message)] = 'Orange'
    elif 'Yellow' in message or 'MAX  To City Center' in message:
        message_dict[str(message)] = 'Yellow'
    else:
        message_dict[str(message)] = 'No Color'
        print(message)
        
message_dict
# Out:
# MAX  to Gresham - MAX to Portland Airport
# {'MAX  Red Line to Airport': 'Red',
#  'MAX  Red Line to City Center & Beaverton': 'Red',
#  'MAX  Blue Line to Gresham': 'Blue',
#  'MAX  Blue Line to Ruby Junction/E 197th Ave': 'Blue',
#  'MAX  Blue Line to Elmonica/170th': 'Blue',
#  'MAX  Blue Line to Hillsboro': 'Blue',
#  'MAX  Blue Line to Willow Creek/SW 185th Ave': 'Blue',
#  'MAX  Yellow Line to Expo Center': 'Yellow',
#  'MAX  Yellow Line to City Center/Milwaukie': 'Yellow',
#  'MAX  Yellow Line to Interstate/Rose Quarter': 'Yellow',
#  'MAX  Green Line to Clackamas Town Center': 'Green',
#  'MAX  Green Line to Gateway TC': 'Green',
#  'MAX  Green Line to City Center/PSU': 'Green',
#  'MAX  Orange Line to City Center/Expo Center': 'Orange',
#  'MAX  Orange Line to City Center/PSU': 'Orange',
#  'MAX  Orange Line to Milwaukie': 'Orange',
#  'MAX  Blue Line to Gateway TC': 'Blue',
#  'MAX  Blue Line to City Center': 'Blue',
#  'MAX  Blue Line to Rose Qtr': 'Blue',
#  'MAX  To City Center': 'Yellow',
#  'MAX  Yellow Line to City Center/PSU': 'Yellow',
#  'MAX  Blue Line to Rose Quarter TC': 'Blue',
#  'MAX  Red Line to PSU': 'Red',
#  'MAX  to Gresham - MAX to Portland Airport': 'No Color',
#  'MAX  Blue Line to City Center and Hillsboro': 'Blue',
#  'MAX  Blue Line to PSU': 'Blue',
#  'MAX  Green Line to Rose Quarter TC': 'Green',
#  'MAX  Yellow Line to City Center': 'Yellow'}

# %%
rail['lineColor'] = rail['signMessageLong'].map(message_dict)
rail.head()
# Out:
#    bearing  blockID  delay  direction           timestamp garage  lastLocID  \
# 0       42     9043   -138          0 2016-12-31 16:05:35   ELMO      10572
# 1      270     9043   -107          0 2016-12-31 16:07:26   ELMO      10574
# 2      299     9043   -138          0 2016-12-31 16:10:39   ELMO      10576
# 3        1     9043   -136          0 2016-12-31 16:04:51   ELMO      11616
# 4       42     9043   -138          0 2016-12-31 16:05:35   ELMO      10572
#
#    lastStopSeq  messageCode  nextLocID  nextStopSeq  routeNumber  \
# 0           23          927      10574           24           90
# 1           24          927      10576           25           90
# 2           25          927      10579           26           90
# 3           22          927      10572           23           90
# 4           23          927      10574           24           90
#
#             signMessageLong   tripID  type  vehicle_id  \
# 0  MAX  Red Line to Airport  6997146  rail         416
# 1  MAX  Red Line to Airport  6997146  rail         416
# 2  MAX  Red Line to Airport  6997146  rail         416
# 3  MAX  Red Line to Airport  6997146  rail         416
# 4  MAX  Red Line to Airport  6997146  rail         417
#
#    vehicle_location_longitude  vehicle_location_latitude  hour lineColor
# 0                 -122.563200                  45.560901    16       Red
# 1                 -122.561480                  45.572588    16       Red
# 2                 -122.571721                  45.580453    16       Red
# 3                 -122.567106                  45.556137    16       Red
# 4                 -122.563200                  45.560901    16       Red

# %%
rail[['routeNumber', 'lineColor','delay']].groupby(['routeNumber', 'lineColor']).count()
# Out:
#                          delay
# routeNumber lineColor
# 90          Red         869139
# 100         Blue       2442917
#             No Color     61687
#             Red          23870
# 190         Orange           8
#             Yellow      585471
# 200         Green       886290
# 290         Orange      592042

# %%
# Remove "No Color" lines
rail_clean = rail.loc[rail['lineColor']!='No Color',:]

rail_clean = rail_clean.loc[(rail_clean['routeNumber']!=100) | (rail_clean['lineColor']!='Red')]

rail_clean = rail_clean.loc[(rail_clean['routeNumber']!=190) | (rail_clean['lineColor']!='Orange'),:]

rail_clean[['routeNumber', 'lineColor','delay']].groupby(['routeNumber', 'lineColor']).count()
# Out:
#                          delay
# routeNumber lineColor
# 90          Red         869139
# 100         Blue       2442917
# 190         Yellow      585471
# 200         Green       886290
# 290         Orange      592042

# %% [markdown]
# What's the total number of events by line? This gives us an idea of how busy each line was in the 6-month period.

# %%
rail_clean[['lineColor', 'timestamp']].groupby('lineColor').count()
# Out:
#            timestamp
# lineColor
# Blue         2442917
# Green         886290
# Orange        592042
# Red           869139
# Yellow        585471

# %% [markdown]
# ## Delay Counts by Route

# %% [markdown]
# Now that the data is ready, we can answer the first question:
#
#     1. Which routes have the most delays?

# %%
# Take a subset of the data that includes the routeNumber, lineColor, and delay columns,
#and only rows where the delay is negative.
#Perform a groupby on lineColor or routeNumber using count.
#This just counts the total number of timestamps in each category.
delay_count_route = rail_clean[['routeNumber','lineColor','delay']].loc[rail_clean['delay']<0].groupby(['routeNumber', 'lineColor']).count().sort_values('delay', ascending=False).reset_index()
delay_count_route
# Out:
#    routeNumber lineColor    delay
# 0          100      Blue  1715426
# 1          200     Green   629591
# 2           90       Red   577302
# 3          290    Orange   459261
# 4          190    Yellow   437277

# %%
# Define RGB for rail line colors
lineColors={'Blue':'rgba(0, 102, 204, 0.8)', 
       'Green':'rgba(51, 204, 51, 0.8)',
       'Red':'rgba(255, 0, 0, 0.8)', 
       'Orange':'rgba(255, 128, 0, 0.8)',
       'Yellow':'rgba(236, 236, 19, 0.8)'}

# %%
colors = list(lineColors.values())

data = [go.Bar(x=delay_count_route['lineColor'],
            y=delay_count_route['delay'],
       marker=dict(
       color=colors,
       line=dict(color='rgba(0, 77, 102, .5)',
            width=1,)))]

layout = go.Layout(
    yaxis={'title':'Delay Count', 'titlefont':{'size':16}},
    xaxis={'title':'Rail Line', 'titlefont':{'size':16}},
    showlegend=False,
    margin=dict(t=50)
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='delay-count-route.html')
# Out:
# <div id="4c6b6b4c-ad9e-46b0-b09c-1d61d3a264c0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '4c6b6b4c-ad9e-46b0-b09c-1d61d3a264c0',
#             [{"marker": {"color": ["rgba(0, 102, 204, 0.8)", "rgba(51, 204, 51, 0.8)", "rgba(255, 0, 0, 0.8)", "rgba(255, 128, 0, 0.8)", "rgba(236, 236, 19, 0.8)"], "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "x": ["Blue", "Green", "Red", "Orange", "Yellow"], "y": [1715426.0, 629591.0, 577302.0, 459261.0, 437277.0], "type": "bar", "uid": "a7499c34-afac-11e8-8218-e442a6f8adc6"}],
#             {"margin": {"t": 50}, "showlegend": false, "xaxis": {"title": "Rail Line", "titlefont": {"size": 16}}, "yaxis": {"title": "Delay Count", "titlefont": {"size": 16}}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('4c6b6b4c-ad9e-46b0-b09c-1d61d3a264c0',{});}).then(function(){Plotly.animate('4c6b6b4c-ad9e-46b0-b09c-1d61d3a264c0');})
#         });</script>

# %% [markdown]
# We can also break the delay count down by signMessageLong.

# %%
delay_count_message = rail_clean[['routeNumber', 'lineColor', 'signMessageLong','delay']].loc[rail_clean['delay']<0].groupby(['routeNumber', 'lineColor', 'signMessageLong']).count().sort_values('delay').reset_index()
delay_count_message
# Out:
#     routeNumber lineColor                              signMessageLong   delay
# 0           190    Yellow              MAX  Yellow Line to City Center       2
# 1           190    Yellow                          MAX  To City Center    2275
# 2           100      Blue            MAX  Blue Line to Rose Quarter TC    3127
# 3           100      Blue                   MAX  Blue Line to Rose Qtr    4132
# 4           190    Yellow          MAX  Yellow Line to City Center/PSU    4895
# 5           190    Yellow  MAX  Yellow Line to Interstate/Rose Quarter    8256
# 6           100      Blue                MAX  Blue Line to City Center   12421
# 7            90       Red                         MAX  Red Line to PSU   12445
# 8           290    Orange          MAX  Orange Line to City Center/PSU   13744
# 9           100      Blue                        MAX  Blue Line to PSU   14139
# 10          100      Blue                 MAX  Blue Line to Gateway TC   15100
# 11          200     Green           MAX  Green Line to Rose Quarter TC   18587
# 12          200     Green                MAX  Green Line to Gateway TC   23557
# 13          100      Blue  MAX  Blue Line to City Center and Hillsboro   30347
# 14          100      Blue             MAX  Blue Line to Elmonica/170th   32473
# 15          100      Blue  MAX  Blue Line to Willow Creek/SW 185th Ave   48503
# 16          100      Blue  MAX  Blue Line to Ruby Junction/E 197th Ave  101617
# 17          190    Yellow    MAX  Yellow Line to City Center/Milwaukie  116157
# 18          290    Orange  MAX  Orange Line to City Center/Expo Center  161949
# 19          200     Green           MAX  Green Line to City Center/PSU  268274
# 20           90       Red     MAX  Red Line to City Center & Beaverton  268686
# 21          290    Orange                MAX  Orange Line to Milwaukie  283568
# 22           90       Red                     MAX  Red Line to Airport  296171
# 23          190    Yellow              MAX  Yellow Line to Expo Center  305692
# 24          200     Green     MAX  Green Line to Clackamas Town Center  319173
# 25          100      Blue                    MAX  Blue Line to Gresham  681006
# 26          100      Blue                  MAX  Blue Line to Hillsboro  772561

# %%
colors = []
for row in delay_count_message.index:
    color = delay_count_message.loc[row,'lineColor']
    colors.append(lineColors[str(color)])
colors

data = [go.Bar(x=delay_count_message['delay'],
            y=delay_count_message['signMessageLong'],
               orientation = 'h',
       marker=dict(
       color=colors,
       line=dict(color='rgba(0, 77, 102, .5)',
            width=1,)))]

layout = go.Layout(
    title='Delay Counts by Sign Message',
    yaxis=dict(title='Sign Message', titlefont=dict(size=16),
                  tickfont=dict(size=12),
                  ),
    xaxis={'title':'Delay Count', 'titlefont':{'size':16}},
    showlegend=False,
    margin=dict(pad=5,
    l=350,
    r=100),
    height=700
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='delay-count-signMessage.html')
# Out:
# <div id="18efb90a-5729-4e35-8688-8eb66cd96f08" style="height: 700px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '18efb90a-5729-4e35-8688-8eb66cd96f08',
#             [{"marker": {"color": ["rgba(236, 236, 19, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(255, 0, 0, 0.8)", "rgba(255, 128, 0, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(51, 204, 51, 0.8)", "rgba(51, 204, 51, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(255, 128, 0, 0.8)", "rgba(51, 204, 51, 0.8)", "rgba(255, 0, 0, 0.8)", "rgba(255, 128, 0, 0.8)", "rgba(255, 0, 0, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(51, 204, 51, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(0, 102, 204, 0.8)"], "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "orientation": "h", "x": [2.0, 2275.0, 3127.0, 4132.0, 4895.0, 8256.0, 12421.0, 12445.0, 13744.0, 14139.0, 15100.0, 18587.0, 23557.0, 30347.0, 32473.0, 48503.0, 101617.0, 116157.0, 161949.0, 268274.0, 268686.0, 283568.0, 296171.0, 305692.0, 319173.0, 681006.0, 772561.0], "y": ["MAX  Yellow Line to City Center", "MAX  To City Center", "MAX  Blue Line to Rose Quarter TC", "MAX  Blue Line to Rose Qtr", "MAX  Yellow Line to City Center/PSU", "MAX  Yellow Line to Interstate/Rose Quarter", "MAX  Blue Line to City Center", "MAX  Red Line to PSU", "MAX  Orange Line to City Center/PSU", "MAX  Blue Line to PSU", "MAX  Blue Line to Gateway TC", "MAX  Green Line to Rose Quarter TC", "MAX  Green Line to Gateway TC", "MAX  Blue Line to City Center and Hillsboro", "MAX  Blue Line to Elmonica/170th", "MAX  Blue Line to Willow Creek/SW 185th Ave", "MAX  Blue Line to Ruby Junction/E 197th Ave", "MAX  Yellow Line to City Center/Milwaukie", "MAX  Orange Line to City Center/Expo Center", "MAX  Green Line to City Center/PSU", "MAX  Red Line to City Center & Beaverton", "MAX  Orange Line to Milwaukie", "MAX  Red Line to Airport", "MAX  Yellow Line to Expo Center", "MAX  Green Line to Clackamas Town Center", "MAX  Blue Line to Gresham", "MAX  Blue Line to Hillsboro"], "type": "bar", "uid": "a8006c98-afac-11e8-a8d2-e442a6f8adc6"}],
#             {"height": 700, "margin": {"l": 350, "pad": 5, "r": 100}, "showlegend": false, "title": "Delay Counts by Sign Message", "xaxis": {"title": "Delay Count", "titlefont": {"size": 16}}, "yaxis": {"tickfont": {"size": 12}, "title": "Sign Message", "titlefont": {"size": 16}}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('18efb90a-5729-4e35-8688-8eb66cd96f08',{});}).then(function(){Plotly.animate('18efb90a-5729-4e35-8688-8eb66cd96f08');})
#         });</script>

# %% [markdown]
# ## Normalized Delay Counts by Routes

# %%
norm_delay_message = (rail_clean[['routeNumber', 'lineColor', 'signMessageLong','delay']].loc[rail_clean['delay']<0].groupby(['routeNumber', 'lineColor', 'signMessageLong']).count()/rail_clean[['signMessageLong','delay']].groupby('signMessageLong').count()).sort_values('delay').reset_index()
norm_delay_message
# Out:
#     routeNumber lineColor                              signMessageLong  \
# 0           100      Blue                MAX  Blue Line to City Center
# 1           100      Blue            MAX  Blue Line to Rose Quarter TC
# 2           100      Blue                   MAX  Blue Line to Rose Qtr
# 3           190    Yellow  MAX  Yellow Line to Interstate/Rose Quarter
# 4           100      Blue                 MAX  Blue Line to Gateway TC
# 5           190    Yellow    MAX  Yellow Line to City Center/Milwaukie
# 6            90       Red                     MAX  Red Line to Airport
# 7           200     Green           MAX  Green Line to Rose Quarter TC
# 8           190    Yellow          MAX  Yellow Line to City Center/PSU
# 9           100      Blue  MAX  Blue Line to City Center and Hillsboro
# 10          200     Green           MAX  Green Line to City Center/PSU
# 11          100      Blue                    MAX  Blue Line to Gresham
# 12          200     Green                MAX  Green Line to Gateway TC
# 13           90       Red     MAX  Red Line to City Center & Beaverton
# 14          100      Blue                  MAX  Blue Line to Hillsboro
# 15          100      Blue             MAX  Blue Line to Elmonica/170th
# 16          200     Green     MAX  Green Line to Clackamas Town Center
# 17          290    Orange  MAX  Orange Line to City Center/Expo Center
# 18          290    Orange                MAX  Orange Line to Milwaukie
# 19          100      Blue  MAX  Blue Line to Ruby Junction/E 197th Ave
# 20          100      Blue                        MAX  Blue Line to PSU
# 21          290    Orange          MAX  Orange Line to City Center/PSU
# 22          100      Blue  MAX  Blue Line to Willow Creek/SW 185th Ave
# 23          190    Yellow              MAX  Yellow Line to Expo Center
# 24           90       Red                         MAX  Red Line to PSU
# 25          190    Yellow                          MAX  To City Center
# 26          190    Yellow              MAX  Yellow Line to City Center
#
#        delay
# 0   0.400329
# 1   0.431132
# 2   0.440136
# 3   0.527371
# 4   0.556128
# 5   0.571136
# 6   0.624559
# 7   0.637458
# 8   0.637785
# 9   0.642632
# 10  0.675542
# 11  0.683533
# 12  0.694548
# 13  0.706050
# 14  0.716499
# 15  0.729730
# 16  0.749072
# 17  0.765112
# 18  0.780165
# 19  0.801560
# 20  0.809933
# 21  0.813110
# 22  0.842139
# 23  0.858172
# 24  0.865258
# 25  0.893208
# 26  1.000000

# %%
colors = []
for row in norm_delay_message.index:
    color = norm_delay_message.loc[row,'lineColor']
    colors.append(lineColors[str(color)])
colors

data = [go.Bar(x=norm_delay_message['delay'],
            y=norm_delay_message['signMessageLong'],
               orientation = 'h',
       marker=dict(
       color=colors,
       line=dict(color='rgba(0, 77, 102, .5)',
            width=1,)))]

layout = go.Layout(
    title='Percent of Time a Line is Delayed',
    yaxis=dict(title='Sign Message', titlefont=dict(size=16),
                  tickfont=dict(size=12),
                  ),
    xaxis={'title':'Delay Fraction (%)', 'titlefont':{'size':16}},
    showlegend=False,
    margin=dict(pad=5,
    l=350,
    r=100),
    height=700
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='delay-count-signMessage-norm.html')
# Out:
# <div id="9dc51a24-03d6-4b78-9eef-6988ce348105" style="height: 700px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '9dc51a24-03d6-4b78-9eef-6988ce348105',
#             [{"marker": {"color": ["rgba(0, 102, 204, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(255, 0, 0, 0.8)", "rgba(51, 204, 51, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(51, 204, 51, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(51, 204, 51, 0.8)", "rgba(255, 0, 0, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(51, 204, 51, 0.8)", "rgba(255, 128, 0, 0.8)", "rgba(255, 128, 0, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(255, 128, 0, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(255, 0, 0, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(236, 236, 19, 0.8)"], "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "orientation": "h", "x": [0.40032874593096335, 0.43113194540190264, 0.44013634426927994, 0.5273714468221016, 0.5561284619917501, 0.5711356629740534, 0.6245592651326001, 0.6374579875162906, 0.637785016286645, 0.6426317684179319, 0.6755421480444396, 0.6835330215807841, 0.6945484565262258, 0.7060502223109831, 0.7164985694345904, 0.7297303370786516, 0.7490723812518922, 0.7651121809256993, 0.7801646344147555, 0.8015602568349978, 0.8099329781749441, 0.8131100987990297, 0.8421390745724455, 0.858171936453751, 0.8652575957727873, 0.8932076953278367, 1.0], "y": ["MAX  Blue Line to City Center", "MAX  Blue Line to Rose Quarter TC", "MAX  Blue Line to Rose Qtr", "MAX  Yellow Line to Interstate/Rose Quarter", "MAX  Blue Line to Gateway TC", "MAX  Yellow Line to City Center/Milwaukie", "MAX  Red Line to Airport", "MAX  Green Line to Rose Quarter TC", "MAX  Yellow Line to City Center/PSU", "MAX  Blue Line to City Center and Hillsboro", "MAX  Green Line to City Center/PSU", "MAX  Blue Line to Gresham", "MAX  Green Line to Gateway TC", "MAX  Red Line to City Center & Beaverton", "MAX  Blue Line to Hillsboro", "MAX  Blue Line to Elmonica/170th", "MAX  Green Line to Clackamas Town Center", "MAX  Orange Line to City Center/Expo Center", "MAX  Orange Line to Milwaukie", "MAX  Blue Line to Ruby Junction/E 197th Ave", "MAX  Blue Line to PSU", "MAX  Orange Line to City Center/PSU", "MAX  Blue Line to Willow Creek/SW 185th Ave", "MAX  Yellow Line to Expo Center", "MAX  Red Line to PSU", "MAX  To City Center", "MAX  Yellow Line to City Center"], "type": "bar", "uid": "a921fe98-afac-11e8-b377-e442a6f8adc6"}],
#             {"height": 700, "margin": {"l": 350, "pad": 5, "r": 100}, "showlegend": false, "title": "Percent of Time a Line is Delayed", "xaxis": {"title": "Delay Fraction (%)", "titlefont": {"size": 16}}, "yaxis": {"tickfont": {"size": 12}, "title": "Sign Message", "titlefont": {"size": 16}}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('9dc51a24-03d6-4b78-9eef-6988ce348105',{});}).then(function(){Plotly.animate('9dc51a24-03d6-4b78-9eef-6988ce348105');})
#         });</script>

# %%
norm_delay_routes = (rail_clean[['routeNumber','lineColor', 'delay']].loc[rail_clean['delay']<0].groupby(['routeNumber', 'lineColor']).count()/rail_clean[['routeNumber', 'delay']].groupby('routeNumber').count()).sort_values('delay', ascending=False).reset_index()
norm_delay_routes
# Out:
#    routeNumber lineColor     delay
# 0          290    Orange  0.775724
# 1          190    Yellow  0.746881
# 2          200     Green  0.710367
# 3          100      Blue  0.702204
# 4           90       Red  0.664223

# %%
colors = []
for row in norm_delay_routes.index:
    color = norm_delay_routes.loc[row,'lineColor']
    colors.append(lineColors[str(color)])
colors

data = [go.Bar(x=norm_delay_routes['lineColor'],
            y=norm_delay_routes['delay']*100,
       marker=dict(
       color=colors,
       line=dict(color='rgba(0, 77, 102, .5)',
            width=1,)))]

layout = go.Layout(
    yaxis={'title':'Delay Fraction (%)', 'titlefont':{'size':16}},
    xaxis={'title':'Rail Line', 'titlefont':{'size':16}},
    showlegend=False,
    margin=dict(t=50)
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='delay-route-norm.html')
# Out:
# <div id="ccb3f58b-1739-4917-93d1-d73f41f98d7f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'ccb3f58b-1739-4917-93d1-d73f41f98d7f',
#             [{"marker": {"color": ["rgba(255, 128, 0, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(51, 204, 51, 0.8)", "rgba(0, 102, 204, 0.8)", "rgba(255, 0, 0, 0.8)"], "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "x": ["Orange", "Yellow", "Green", "Blue", "Red"], "y": [77.57236817658206, 74.68807165512895, 71.03668099606224, 70.22039635403085, 66.42228688391614], "type": "bar", "uid": "a9a975f6-afac-11e8-b006-e442a6f8adc6"}],
#             {"margin": {"t": 50}, "showlegend": false, "xaxis": {"title": "Rail Line", "titlefont": {"size": 16}}, "yaxis": {"title": "Delay Fraction (%)", "titlefont": {"size": 16}}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('ccb3f58b-1739-4917-93d1-d73f41f98d7f',{});}).then(function(){Plotly.animate('ccb3f58b-1739-4917-93d1-d73f41f98d7f');})
#         });</script>

# %% [markdown]
# ## Total delay by Line

# %%
idx = rail_clean[['routeNumber',
          'lineColor', 
          'tripID', 
          'vehicle_id', 
          'signMessageLong', 
          'lastStopSeq']
        ].groupby(['routeNumber', 
          'lineColor', 
          'tripID',  
          'vehicle_id', 
          'signMessageLong']
                 )['lastStopSeq'].transform('max') == rail_clean['lastStopSeq']

delay_route_sum = rail_clean.loc[idx, ['lineColor','delay']
        ].loc[rail_clean.loc[idx,'delay']<0].groupby(['lineColor']
                                              ).sum().sort_values('delay').reset_index()
delay_route_sum
# Out:
#   lineColor    delay
# 0      Blue -9525584
# 1    Yellow -5681365
# 2       Red -4118455
# 3    Orange -4084661
# 4     Green -3040831

# %%
delay_route_mean = rail_clean.loc[idx, ['lineColor','delay']
        ].loc[rail_clean.loc[idx,'delay']<0].groupby(['lineColor']
                                              ).mean().sort_values('delay').reset_index()
delay_route_mean
# Out:
#   lineColor       delay
# 0       Red -272.204560
# 1      Blue -266.137237
# 2     Green -231.347459
# 3    Yellow -213.200428
# 4    Orange -196.993537

# %%
# Order the lastLocID starting with the largest total delay.
delay_route_mean['lineColor_cat'] = pd.Categorical(
    delay_route_mean['lineColor'], 
    categories=[val for val in delay_route_sum['lineColor']],
    ordered=True
)
delay_route_mean = delay_route_mean.sort_values('lineColor_cat').reset_index(drop=True).drop('lineColor_cat', axis=1)
delay_route_mean
# Out:
#   lineColor       delay
# 0      Blue -266.137237
# 1    Yellow -213.200428
# 2       Red -272.204560
# 3    Orange -196.993537
# 4     Green -231.347459

# %%
colors = []
for row in delay_route_sum.index:
    color = delay_route_sum.loc[row,'lineColor']
    colors.append(lineColors[str(color)])
colors

trace0 = go.Bar(
    name='Total Delay',
    x=delay_route_sum['lineColor'],
    y=-delay_route_sum['delay']/60/60,
    showlegend=True,
    marker=dict(
        color=colors,
        line=dict(color='rgba(0, 77, 102, .5)',
            width=1,)
    )
)
trace1 = go.Scatter(
    name='Average Delay',
    x=delay_route_mean['lineColor'],
    y=-delay_route_mean['delay'],
    yaxis='y2',
    line = dict(
        color = ('rgb(0, 51, 102)'),
        width = 4)
                    
)

data = [trace0, trace1]
layout = go.Layout(
    yaxis={'title':'Delay (hours)', 'titlefont':{'size':16}},
    xaxis={'title':'Rail Line', 'titlefont':{'size':16}},
    showlegend=True,
    legend=dict(font=dict(size=14),
               orientation='h',
               y=1.1),
    barmode='group',
    yaxis2=dict(title='Delay (seconds)',
                overlaying='y',
                side='right'
    ),
    margin=dict(b=100,
               t=50)
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='delay-route.html')
# Out:
# <div id="f29766af-3dfe-4d3f-b839-c96f04253b86" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'f29766af-3dfe-4d3f-b839-c96f04253b86',
#             [{"marker": {"color": ["rgba(0, 102, 204, 0.8)", "rgba(236, 236, 19, 0.8)", "rgba(255, 0, 0, 0.8)", "rgba(255, 128, 0, 0.8)", "rgba(51, 204, 51, 0.8)"], "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "name": "Total Delay", "showlegend": true, "x": ["Blue", "Yellow", "Red", "Orange", "Green"], "y": [2645.9955555555557, 1578.1569444444444, 1144.0152777777778, 1134.6280555555556, 844.6752777777779], "type": "bar", "uid": "aaebb768-afac-11e8-bcf9-e442a6f8adc6"}, {"line": {"color": "rgb(0, 51, 102)", "width": 4}, "name": "Average Delay", "x": ["Blue", "Yellow", "Red", "Orange", "Green"], "y": [266.13723737147967, 213.20042779945962, 272.2045604758757, 196.99353749698577, 231.34745891661595], "yaxis": "y2", "type": "scatter", "uid": "aaebb769-afac-11e8-93d7-e442a6f8adc6"}],
#             {"barmode": "group", "legend": {"font": {"size": 14}, "orientation": "h", "y": 1.1}, "margin": {"b": 100, "t": 50}, "showlegend": true, "xaxis": {"title": "Rail Line", "titlefont": {"size": 16}}, "yaxis": {"title": "Delay (hours)", "titlefont": {"size": 16}}, "yaxis2": {"overlaying": "y", "side": "right", "title": "Delay (seconds)"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('f29766af-3dfe-4d3f-b839-c96f04253b86',{});}).then(function(){Plotly.animate('f29766af-3dfe-4d3f-b839-c96f04253b86');})
#         });</script>

# %% [markdown]
# ## Total Delay by StopID

# %%
# Check that each stop is associated with only one line color
locID_lineColor = rail_clean[['lineColor', 'lastLocID']].groupby(['lastLocID']).nunique()
locID_lineColor.head()
# Out:
#            lineColor  lastLocID
# lastLocID
# 7601               5          1
# 7606               5          1
# 7608               5          1
# 7618               5          1
# 7627               5          1

# %%
tdelay_stopID = rail_clean[['lastLocID', 'delay']].groupby(['lastLocID']).sum().sort_values('delay').reset_index()
tdelay_stopID[0:10]
# Out:
#    lastLocID     delay
# 0       8347 -13231372
# 1       8346 -10470551
# 2       8345  -9590337
# 3       8344  -8603169
# 4       8341  -8505411
# 5       8371  -8489995
# 6       8343  -8454713
# 7       8350  -7901631
# 8       8384  -7876735
# 9       8342  -7712741

# %%
locID_lineColor.loc[locID_lineColor.index.isin(tdelay_stopID.loc[:10,'lastLocID']),:]
# Out:
#            lineColor  lastLocID
# lastLocID
# 8341               3          1
# 8342               3          1
# 8343               3          1
# 8344               3          1
# 8345               3          1
# 8346               3          1
# 8347               3          1
# 8350               1          1
# 8371               3          1
# 8377               3          1
# 8384               2          1

# %% [markdown]
# So the only stop that belongs to a unique lineColor is 8350. Let's see what lines each of the stops belong to.

# %%
top10 = rail_clean.loc[rail_clean['lastLocID'].isin(tdelay_stopID.loc[:9,'lastLocID']),['lineColor', 'lastLocID', 'delay']]
top10[:10]
# Out:
#    lineColor  lastLocID  delay
# 8        Red       8342     58
# 9        Red       8343     68
# 10       Red       8344     76
# 11       Red       8345     64
# 12       Red       8346     25
# 17       Red       8342     58
# 18       Red       8343     68
# 19       Red       8344     76
# 20       Red       8345     64
# 21       Red       8346     25

# %%
top10 = top10.groupby(['lastLocID','lineColor']).sum().reset_index()
top10[:10]
# Out:
#    lastLocID lineColor    delay
# 0       8341      Blue -3831808
# 1       8341     Green -2364557
# 2       8341       Red -2309046
# 3       8342      Blue -3548207
# 4       8342     Green -2093214
# 5       8342       Red -2071320
# 6       8343      Blue -3931412
# 7       8343     Green -2304109
# 8       8343       Red -2219192
# 9       8344      Blue -4123368

# %%
[val for val in tdelay_stopID.loc[:9,'lastLocID']]
# Out:
# [8347, 8346, 8345, 8344, 8341, 8371, 8343, 8350, 8384, 8342]

# %%
# Order the lastLocID starting with the largest total delay.
top10['lastLocID_cat'] = pd.Categorical(
    top10['lastLocID'], 
    categories=[val for val in tdelay_stopID.loc[:9,'lastLocID']],
    ordered=True
)
top10 = top10.sort_values('lastLocID_cat').reset_index(drop=True).drop('lastLocID_cat', axis=1)
top10[:10]
# Out:
#    lastLocID lineColor    delay
# 0       8347       Red -2696563
# 1       8347     Green -3786845
# 2       8347      Blue -6747964
# 3       8346       Red -2638280
# 4       8346     Green -2845667
# 5       8346      Blue -4986604
# 6       8345     Green -2593475
# 7       8345       Red -2419728
# 8       8345      Blue -4577134
# 9       8344      Blue -4123368

# %%
# Blue line
trace0 = go.Bar(
    x=top10.loc[top10['lineColor']=='Blue','lastLocID'],
    y=-top10.loc[top10['lineColor']=='Blue','delay']/60/60,
    name='Blue Line',
    marker=dict(
        color=lineColors['Blue'],
        line=dict(color='rgba(0, 77, 102, .5)', width=1)
    )
)
# Green Line
trace1 = go.Bar(
    x=top10.loc[top10['lineColor']=='Green','lastLocID'],
    y=-top10.loc[top10['lineColor']=='Green','delay']/60/60,
    name='Green Line',
    marker=dict(
        color=lineColors['Green'],
        line=dict(color='rgba(0, 77, 102, .5)', width=1)
    )
)
# Red Line
trace2 = go.Bar(
    x=top10.loc[top10['lineColor']=='Red','lastLocID'],
    y=-top10.loc[top10['lineColor']=='Red','delay']/60/60,
    name='Red Line',
    marker=dict(
        color=lineColors['Red'],
        line=dict(color='rgba(0, 77, 102, .5)', width=1)
    )
)
# Total delay by stop ID
trace3 = go.Scatter(
    x=top10.loc[top10['lineColor']=='Blue','lastLocID'],
    y=-tdelay_stopID.loc[0:10,'delay']/60/60,
    yaxis='y2',
    name='Total Delay',
    line = dict(
        color = ('rgb(0, 51, 102)'),
        width = 4)
)

data = [trace0, trace1, trace2, trace3]

# Format the figure
layout = go.Layout(
    yaxis=dict(title='Delay (hours)',
              titlefont=dict(size=16),
              tickfont=dict(size=14)),
    xaxis=dict(title='Stop ID',
              titlefont=dict(size=16),
              type='category',
              tickangle=-45,
              tickfont=dict(size=14)),
    legend=dict(font=dict(size=14),
               orientation='h',
               y=1.1),
    barmode='group',
    yaxis2=dict(title='Delay (hours)',
                overlaying='y',
                side='right'
    ),
    margin=dict(b=100,
               t=50)
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='totalDelay-top10-byLine.html')
# Out:
# <div id="25754b1e-1e96-40de-bb9d-bf2fb60d1257" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '25754b1e-1e96-40de-bb9d-bf2fb60d1257',
#             [{"marker": {"color": "rgba(0, 102, 204, 0.8)", "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "name": "Blue Line", "x": [8347.0, 8346.0, 8345.0, 8344.0, 8341.0, 8371.0, 8343.0, 8350.0, 8384.0, 8342.0], "y": [1874.4344444444444, 1385.1677777777777, 1271.4261111111111, 1145.38, 1064.391111111111, 1069.335, 1092.058888888889, 2194.8975, 1431.141111111111, 985.6130555555555], "type": "bar", "uid": "ad19ee50-afac-11e8-98ac-e442a6f8adc6"}, {"marker": {"color": "rgba(51, 204, 51, 0.8)", "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "name": "Green Line", "x": [8347.0, 8346.0, 8345.0, 8344.0, 8341.0, 8371.0, 8343.0, 8342.0], "y": [1051.901388888889, 790.4630555555556, 720.4097222222223, 643.7794444444445, 656.8213888888889, 668.9030555555556, 640.0302777777778, 581.4483333333334], "type": "bar", "uid": "ad19ee51-afac-11e8-9800-e442a6f8adc6"}, {"marker": {"color": "rgba(255, 0, 0, 0.8)", "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "name": "Red Line", "x": [8347.0, 8346.0, 8345.0, 8344.0, 8341.0, 8371.0, 8343.0, 8384.0, 8342.0], "y": [749.0452777777778, 732.8555555555556, 672.1466666666668, 600.6097222222222, 641.4016666666666, 620.0938888888888, 616.4422222222222, 756.8408333333333, 575.3666666666667], "type": "bar", "uid": "ad19ee52-afac-11e8-941a-e442a6f8adc6"}, {"line": {"color": "rgb(0, 51, 102)", "width": 4}, "name": "Total Delay", "x": [8347.0, 8346.0, 8345.0, 8344.0, 8341.0, 8371.0, 8343.0, 8350.0, 8384.0, 8342.0], "y": [3675.3811111111113, 2908.4863888888885, 2663.9825, 2389.7691666666665, 2362.6141666666667, 2358.331944444444, 2348.531388888889, 2194.8975, 2187.9819444444443, 2142.4280555555556, 2123.1138888888886], "yaxis": "y2", "type": "scatter", "uid": "ad19ee53-afac-11e8-86df-e442a6f8adc6"}],
#             {"barmode": "group", "legend": {"font": {"size": 14}, "orientation": "h", "y": 1.1}, "margin": {"b": 100, "t": 50}, "xaxis": {"tickangle": -45, "tickfont": {"size": 14}, "title": "Stop ID", "titlefont": {"size": 16}, "type": "category"}, "yaxis": {"tickfont": {"size": 14}, "title": "Delay (hours)", "titlefont": {"size": 16}}, "yaxis2": {"overlaying": "y", "side": "right", "title": "Delay (hours)"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('25754b1e-1e96-40de-bb9d-bf2fb60d1257',{});}).then(function(){Plotly.animate('25754b1e-1e96-40de-bb9d-bf2fb60d1257');})
#         });</script>

# %%
# generate the same plot as above but for the top 5 only
top5 = rail_clean.loc[rail_clean['lastLocID'].isin(tdelay_stopID.loc[:4,'lastLocID']),['lineColor', 'lastLocID', 'delay']]
top5 = top5.groupby(['lastLocID','lineColor']).sum().reset_index()

# %%
# Order the lastLocID starting with the largest total delay.
top5['lastLocID_cat'] = pd.Categorical(
    top5['lastLocID'], 
    categories=[val for val in tdelay_stopID.loc[:4,'lastLocID']],
    ordered=True
)
top5 = top5.sort_values('lastLocID_cat').reset_index(drop=True).drop('lastLocID_cat', axis=1)
top5[:10]

# generate Plotly graph
trace0 = go.Bar(
    x=top5.loc[top5['lineColor']=='Blue','lastLocID'],
    y=-top5.loc[top5['lineColor']=='Blue','delay']/60/60,
    name='Blue Line',
    marker=dict(
        color=lineColors['Blue'],
        line=dict(color='rgba(0, 77, 102, .5)', width=1)
    )
)
trace1 = go.Bar(
    x=top5.loc[top5['lineColor']=='Green','lastLocID'],
    y=-top5.loc[top5['lineColor']=='Green','delay']/60/60,
    name='Green Line',
    marker=dict(
        color=lineColors['Green'],
        line=dict(color='rgba(0, 77, 102, .5)', width=1)
    )
)
trace2 = go.Bar(
    x=top5.loc[top5['lineColor']=='Red','lastLocID'],
    y=-top5.loc[top5['lineColor']=='Red','delay']/60/60,
    name='Red Line',
    marker=dict(
        color=lineColors['Red'],
        line=dict(color='rgba(0, 77, 102, .5)', width=1)
    )
)
# Total delay by stop ID
trace3 = go.Scatter(
    x=top5.loc[top5['lineColor']=='Blue','lastLocID'],
    y=-tdelay_stopID.loc[0:5,'delay']/60/60,
    yaxis='y2',
    name='Total Delay',
    line = dict(
        color = ('rgb(0, 51, 102)'),
        width = 4)
)

data = [trace0, trace1, trace2, trace3]
layout = go.Layout(
    yaxis=dict(title='Delay (hours)',
              titlefont=dict(size=16)),
    xaxis=dict(title='Stop ID',
              titlefont=dict(size=16),
              type='category',
              tickangle=-45,
              tickfont=dict(size=14)),
    barmode='group',
    yaxis2=dict(title='Delay (hours)',
                overlaying='y',
                side='right'
    ),
    legend=dict(font=dict(size=14),
               orientation='h',
               y=1.1),
    margin=dict(b=100,
               t=50)
)

fig = go.Figure(data=data, layout=layout)
plotly.offline.iplot(fig, filename='totalDelay-top5-byLine.html')
# Out:
# <div id="2dfb6a37-de29-40ee-b017-39c4d5d7183e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '2dfb6a37-de29-40ee-b017-39c4d5d7183e',
#             [{"marker": {"color": "rgba(0, 102, 204, 0.8)", "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "name": "Blue Line", "x": [8347.0, 8346.0, 8345.0, 8344.0, 8341.0], "y": [1874.4344444444444, 1385.1677777777777, 1271.4261111111111, 1145.38, 1064.391111111111], "type": "bar", "uid": "ad401d5a-afac-11e8-b548-e442a6f8adc6"}, {"marker": {"color": "rgba(51, 204, 51, 0.8)", "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "name": "Green Line", "x": [8347.0, 8346.0, 8345.0, 8344.0, 8341.0], "y": [1051.901388888889, 790.4630555555556, 720.4097222222223, 643.7794444444445, 656.8213888888889], "type": "bar", "uid": "ad401d5b-afac-11e8-b0aa-e442a6f8adc6"}, {"marker": {"color": "rgba(255, 0, 0, 0.8)", "line": {"color": "rgba(0, 77, 102, .5)", "width": 1}}, "name": "Red Line", "x": [8347.0, 8346.0, 8345.0, 8344.0, 8341.0], "y": [749.0452777777778, 732.8555555555556, 672.1466666666668, 600.6097222222222, 641.4016666666666], "type": "bar", "uid": "ad401d5c-afac-11e8-ae14-e442a6f8adc6"}, {"line": {"color": "rgb(0, 51, 102)", "width": 4}, "name": "Total Delay", "x": [8347.0, 8346.0, 8345.0, 8344.0, 8341.0], "y": [3675.3811111111113, 2908.4863888888885, 2663.9825, 2389.7691666666665, 2362.6141666666667, 2358.331944444444], "yaxis": "y2", "type": "scatter", "uid": "ad401d5d-afac-11e8-a4b5-e442a6f8adc6"}],
#             {"barmode": "group", "legend": {"font": {"size": 14}, "orientation": "h", "y": 1.1}, "margin": {"b": 100, "t": 50}, "xaxis": {"tickangle": -45, "tickfont": {"size": 14}, "title": "Stop ID", "titlefont": {"size": 16}, "type": "category"}, "yaxis": {"title": "Delay (hours)", "titlefont": {"size": 16}}, "yaxis2": {"overlaying": "y", "side": "right", "title": "Delay (hours)"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('2dfb6a37-de29-40ee-b017-39c4d5d7183e',{});}).then(function(){Plotly.animate('2dfb6a37-de29-40ee-b017-39c4d5d7183e');})
#         });</script>

# %% [markdown]
# Interestingly, the stops with the top 5 longest delays are ones that are shared between the blue, green, and red lines. Also notice that for each stops shown in the plot, the blue line has the largest total delay, followed by the green and red lines. This is consistent across the top 5.

# %% [markdown]
# We saw that the stops with the greatest total delay are stops that are shared between the red, blue and green lines. Let's see where these stops are on a map.

# %% [markdown]
# ### Delays by Stop ID - Maps

# %% [markdown]
# I will be visualization stopID data on maps so for that I'll need to get the latitude and longitude coordinates of each location ID.

# %%
locations = rail_clean[['lastLocID', 'vehicle_location_longitude', 'vehicle_location_latitude']].groupby('lastLocID').mean()
locations[:10]
# Out:
#            vehicle_location_longitude  vehicle_location_latitude
# lastLocID
# 7601                      -122.675525                  45.526292
# 7606                      -122.683077                  45.508800
# 7608                      -122.680410                  45.513553
# 7618                      -122.682205                  45.510263
# 7627                      -122.676564                  45.520613
# 7646                      -122.677978                  45.517998
# 7763                      -122.676478                  45.527948
# 7774                      -122.682016                  45.512795
# 7777                      -122.678573                  45.519224
# 7787                      -122.676583                  45.522824

# %% [markdown]
# I also need to define the coordinates that I want to center my map plots on.

# %%
center_lat = ((locations['vehicle_location_latitude'].max()-locations['vehicle_location_latitude'].min())/2)+locations['vehicle_location_latitude'].min()
center_lon = ((locations['vehicle_location_longitude'].max()-locations['vehicle_location_longitude'].min())/2)+locations['vehicle_location_longitude'].min()

print(center_lat)
print(center_lon)
# Out:
# 45.51807743199744
# -122.70501593510068

# %% [markdown]
# We saw that the stops with the longest delays were all on the red, blue, and green lines. I'll start by visualizing all of the stops for these 3 lines. Then we can plot just the 10 stops and see where they are along these routes.

# %%
# get all stop IDs for red, blue, and green lines
rgb = rail_clean.loc[rail_clean['lineColor'].isin(['Blue','Green','Red']),['lineColor', 'lastLocID']].drop_duplicates()
rgb[:10]
# Out:
#    lineColor  lastLocID
# 0        Red      10572
# 1        Red      10574
# 2        Red      10576
# 3        Red      11616
# 8        Red       8342
# 9        Red       8343
# 10       Red       8344
# 11       Red       8345
# 12       Red       8346
# 26       Red       8333

# %%
rail_clean[['lineColor', 'lastLocID']].groupby(['lineColor']).nunique()
# Out:
#            lineColor  lastLocID
# lineColor
# Blue               1        113
# Green              1         48
# Orange             1         26
# Red                1         65
# Yellow             1         35

# %%
rgb_coords = rgb.set_index('lastLocID').join(locations)
rgb_coords[:10]
# Out:
#           lineColor  vehicle_location_longitude  vehicle_location_latitude
# lastLocID
# 7601          Green                 -122.675525                  45.526292
# 7601            Red                 -122.675525                  45.526292
# 7601           Blue                 -122.675525                  45.526292
# 7606          Green                 -122.683077                  45.508800
# 7606            Red                 -122.683077                  45.508800
# 7606           Blue                 -122.683077                  45.508800
# 7608          Green                 -122.680410                  45.513553
# 7608            Red                 -122.680410                  45.513553
# 7608           Blue                 -122.680410                  45.513553
# 7618          Green                 -122.682205                  45.510263

# %% [markdown]
# Now we have the coordinates for each stop in the Blue, Green, and red lines. I have to add some small amount of random jitter to each stopID so that points for each color line don't overlap on each other.

# %%
jitter = (np.random.rand(len(rgb_coords))-0.5)*.0002
jitter[:20]
# Out:
# array([-9.78878215e-05,  5.96439333e-05, -6.23360374e-05,  1.39097612e-05,
#        -4.62148459e-05,  6.91306741e-05,  7.53684433e-05,  3.69873697e-05,
#         4.57610759e-05, -4.23926959e-05,  8.80178573e-05, -1.09915932e-05,
#         5.93281374e-05, -6.93788133e-05,  8.14867406e-05,  3.20502719e-06,
#         6.23279488e-06, -7.74718410e-05,  5.83160143e-05,  8.59157582e-05])

# %%
rgb_coords_jitter = rgb_coords.copy()
rgb_coords_jitter['vehicle_location_longitude'] = (rgb_coords_jitter['vehicle_location_longitude']+jitter).round(5)
rgb_coords_jitter['vehicle_location_latitude'] = (rgb_coords_jitter['vehicle_location_latitude']+jitter).round(5)
rgb_coords_jitter = rgb_coords_jitter.reset_index()
rgb_coords_jitter[:10]
# Out:
#    lastLocID lineColor  vehicle_location_longitude  vehicle_location_latitude
# 0       7601     Green                  -122.67562                   45.52619
# 1       7601       Red                  -122.67547                   45.52635
# 2       7601      Blue                  -122.67559                   45.52623
# 3       7606     Green                  -122.68306                   45.50881
# 4       7606       Red                  -122.68312                   45.50875
# 5       7606      Blue                  -122.68301                   45.50887
# 6       7608     Green                  -122.68033                   45.51363
# 7       7608       Red                  -122.68037                   45.51359
# 8       7608      Blue                  -122.68036                   45.51360
# 9       7618     Green                  -122.68225                   45.51022

# %%
# Separate each lineColor into its own dataframe
blueLine = rgb_coords_jitter.loc[rgb_coords_jitter['lineColor']=='Blue',:]
greenLine = rgb_coords_jitter.loc[rgb_coords_jitter['lineColor']=='Green',:]
redLine = rgb_coords_jitter.loc[rgb_coords_jitter['lineColor']=='Red',:]

# %%
bLocID = list(map(str, blueLine['lastLocID']))
blueText_all = ['Stop ID: ' + s for s in bLocID]
gLocID = list(map(str, greenLine['lastLocID']))
greenText_all = ['Stop ID: ' + s for s in gLocID]
rLocID = list(map(str, redLine['lastLocID']))
redText_all = ['Stop ID: ' + s for s in rLocID]

# %%
# blue line
trace0 = go.Scattermapbox(
        name='Blue Line',
        lat=blueLine['vehicle_location_latitude'],
        lon=blueLine['vehicle_location_longitude'],
        mode='markers',
        marker=dict(
            size=10,
            color=lineColors['Blue']
        ),
        text=blueText_all
    )

# green line
trace1 = go.Scattermapbox(
        name='Green Line',
        lat=greenLine['vehicle_location_latitude'],
        lon=greenLine['vehicle_location_longitude'],
        mode='markers',
        marker=dict(
            size=10,
            color=lineColors['Green']
        ),
        text=greenText_all
    )

# red line
trace2 = go.Scattermapbox(
        name='Red Line',
        lat=redLine['vehicle_location_latitude'],
        lon=redLine['vehicle_location_longitude'],
        mode='markers',
        marker=dict(
            size=10,
            color=lineColors['Red']
        ),
        text=redText_all
    )

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=center_lat-.005,
            lon=center_lon
        ),
        pitch=0,
        zoom=9,
    ),
    margin=dict(l=0,
               r=0,
               t=30,
               b=50),
    legend=dict(font=dict(size=14),
               orientation='h',
               y=1.1)
    
)

fig = dict(data=[trace0, trace1, trace2], layout=layout)
plotly.offline.iplot(fig, filename='red-green-blue-stops.html')
# Out:
# <div id="73c97e39-c4fd-444a-8eca-a0400e8be2b5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("73c97e39-c4fd-444a-8eca-a0400e8be2b5", [{"lat": [45.52623, 45.50887, 45.5136, 45.51025, 45.52069, 45.51792, 45.5279, 45.51277, 45.51927, 45.52288, 45.51898, 45.51822, 45.51738, 45.5179, 45.52166, 45.52403, 45.52573, 45.53015, 45.53014, 45.53001, 45.53002, 45.5326, 45.52942, 45.53287, 45.52957, 45.52256, 45.52235, 45.5222, 45.52218, 45.52208, 45.52187, 45.51901, 45.51498, 45.50506, 45.50212, 45.50202, 45.50279, 45.50703, 45.51702, 45.52167, 45.5221, 45.52214, 45.52224, 45.52238, 45.52258, 45.52262, 45.53179, 45.53444, 45.52784, 45.53357, 45.53019, 45.53008, 45.53005, 45.52985, 45.52427, 45.52186, 45.51871, 45.51844, 45.51889, 45.51972, 45.52022, 45.52514, 45.52344, 45.50957, 45.52122, 45.52104, 45.52105, 45.49079, 45.50202, 45.51931, 45.49216, 45.49934, 45.49089, 45.49083, 45.49647, 45.49389, 45.50605, 45.5036, 45.51085, 45.50959, 45.51637, 45.51858, 45.52431, 45.52168, 45.53013, 45.53035, 45.52627, 45.52771, 45.53023, 45.52867, 45.52101, 45.5213, 45.52123, 45.52132, 45.52133, 45.52123, 45.52169, 45.50932, 45.51898, 45.5183, 45.51935, 45.51089, 45.51054, 45.51025, 45.52979, 45.53077, 45.53252, 45.52963, 45.51675, 45.50876, 45.50981, 45.50759, 45.53008], "lon": [-122.67559, -122.68301, -122.68036, -122.68222, -122.67648, -122.67806, -122.67652, -122.68204, -122.67853, -122.67653, -122.68092, -122.67789, -122.67557, -122.67349, -122.67149, -122.67143, -122.67137, -122.66348, -122.6608, -122.65672, -122.65115, -122.61996, -122.60154, -122.57642, -122.56381, -122.55096, -122.52862, -122.50832, -122.49248, -122.48239, -122.47505, -122.46693, -122.45744, -122.43417, -122.42427, -122.41909, -122.42793, -122.43855, -122.46253, -122.47408, -122.48117, -122.48944, -122.49901, -122.51955, -122.54132, -122.55987, -122.56439, -122.58125, -122.60966, -122.62421, -122.65504, -122.65915, -122.66388, -122.66638, -122.67143, -122.67145, -122.67307, -122.67677, -122.6783, -122.68072, -122.68336, -122.67657, -122.67545, -122.78216, -122.69067, -122.68828, -122.69074, -122.80323, -122.83593, -122.69208, -122.79971, -122.83112, -122.81074, -122.80504, -122.82455, -122.81787, -122.84387, -122.83911, -122.85326, -122.85057, -122.86759, -122.87382, -122.89257, -122.88417, -122.91285, -122.91704, -122.94959, -122.94289, -122.92864, -122.93732, -122.96613, -122.97132, -122.97617, -122.98038, -122.9867, -122.98267, -122.99083, -122.77888, -122.69665, -122.69263, -122.68273, -122.71381, -122.72381, -122.68333, -122.66713, -122.66929, -122.67142, -122.56353, -122.67989, -122.6836, -122.44516, -122.4403, -122.66587], "marker": {"color": "rgba(0, 102, 204, 0.8)", "size": 10}, "mode": "markers", "name": "Blue Line", "text": ["Stop ID: 7601", "Stop ID: 7606", "Stop ID: 7608", "Stop ID: 7618", "Stop ID: 7627", "Stop ID: 7646", "Stop ID: 7763", "Stop ID: 7774", "Stop ID: 7777", "Stop ID: 7787", "Stop ID: 8333", "Stop ID: 8334", "Stop ID: 8335", "Stop ID: 8336", "Stop ID: 8337", "Stop ID: 8338", "Stop ID: 8339", "Stop ID: 8340", "Stop ID: 8341", "Stop ID: 8342", "Stop ID: 8343", "Stop ID: 8344", "Stop ID: 8345", "Stop ID: 8346", "Stop ID: 8347", "Stop ID: 8348", "Stop ID: 8349", "Stop ID: 8350", "Stop ID: 8351", "Stop ID: 8352", "Stop ID: 8353", "Stop ID: 8354", "Stop ID: 8355", "Stop ID: 8356", "Stop ID: 8357", "Stop ID: 8359", "Stop ID: 8360", "Stop ID: 8361", "Stop ID: 8362", "Stop ID: 8363", "Stop ID: 8364", "Stop ID: 8365", "Stop ID: 8366", "Stop ID: 8367", "Stop ID: 8368", "Stop ID: 8369", "Stop ID: 8370", "Stop ID: 8371", "Stop ID: 8372", "Stop ID: 8373", "Stop ID: 8374", "Stop ID: 8375", "Stop ID: 8376", "Stop ID: 8377", "Stop ID: 8378", "Stop ID: 8379", "Stop ID: 8380", "Stop ID: 8381", "Stop ID: 8382", "Stop ID: 8383", "Stop ID: 8384", "Stop ID: 9299", "Stop ID: 9303", "Stop  ...

# %% [markdown]
# The plot above shows all stop IDs for the blue, green, and red rail lines. A portion of the points overlap between the lines. The small amount of jitter we introduced into the stop coordinates allow us to resolve the overlapping points when zooming in. Hovering over each point displays the stop ID, in addition to the coordinates.

# %% [markdown]
# Now I want to plot only the top 5 stops with the longest delays.

# %%
# Add the coordinates for each stop
top5_coords = top5.set_index('lastLocID').join(locations).reset_index()
top5_coords[:10]
# Out:
#    lastLocID lineColor    delay  vehicle_location_longitude  \
# 0       8341      Blue -3831808                 -122.660870
# 1       8341     Green -2364557                 -122.660870
# 2       8341       Red -2309046                 -122.660870
# 3       8344      Blue -4123368                 -122.619980
# 4       8344     Green -2317606                 -122.619980
# 5       8344       Red -2162195                 -122.619980
# 6       8345      Blue -4577134                 -122.601614
# 7       8345     Green -2593475                 -122.601614
# 8       8345       Red -2419728                 -122.601614
# 9       8346      Blue -4986604                 -122.576508
#
#    vehicle_location_latitude
# 0                  45.530076
# 1                  45.530076
# 2                  45.530076
# 3                  45.532580
# 4                  45.532580
# 5                  45.532580
# 6                  45.529342
# 7                  45.529342
# 8                  45.529342
# 9                  45.532783

# %%
jitter = (np.random.rand(len(top5_coords))-0.5)*.0003
jitter[:20]
# Out:
# array([ 5.99734234e-06, -3.75157133e-05,  6.99311463e-05, -1.03794105e-04,
#         9.16897327e-05, -9.51062073e-05, -3.13608782e-05,  6.43284998e-05,
#         1.18119867e-04,  3.46016596e-05,  1.75955809e-05,  6.46930951e-06,
#         9.04310037e-05, -1.99479382e-05, -1.18206775e-04])

# %%
top5_jitter = top5_coords.copy()
top5_jitter['vehicle_location_longitude'] = (top5_jitter['vehicle_location_longitude'] + jitter).round(5)
top5_jitter['vehicle_location_latitude'] = (top5_jitter['vehicle_location_latitude'] + jitter).round(5)
top5_jitter[:10]
# Out:
#    lastLocID lineColor    delay  vehicle_location_longitude  \
# 0       8341      Blue -3831808                  -122.66086
# 1       8341     Green -2364557                  -122.66091
# 2       8341       Red -2309046                  -122.66080
# 3       8344      Blue -4123368                  -122.62008
# 4       8344     Green -2317606                  -122.61989
# 5       8344       Red -2162195                  -122.62008
# 6       8345      Blue -4577134                  -122.60165
# 7       8345     Green -2593475                  -122.60155
# 8       8345       Red -2419728                  -122.60150
# 9       8346      Blue -4986604                  -122.57647
#
#    vehicle_location_latitude
# 0                   45.53008
# 1                   45.53004
# 2                   45.53015
# 3                   45.53248
# 4                   45.53267
# 5                   45.53248
# 6                   45.52931
# 7                   45.52941
# 8                   45.52946
# 9                   45.53282

# %%
blueLine_top5 = top5_jitter.loc[top5_jitter['lineColor']=='Blue',:]
greenLine_top5 = top5_jitter.loc[top5_jitter['lineColor']=='Green',:]
redLine_top5 = top5_jitter.loc[top5_jitter['lineColor']=='Red',:]

# %%
bdelays = list(map(str, blueLine_top5['delay']))
blueDelays = ['Delay: ' + s for s in bdelays]
bLocID = list(map(str, blueLine_top5['lastLocID']))
blueLocID = ['Stop ID: ' + s for s in bLocID]

blueText = []
for idx in range(len(blueLocID)):
    blueText.append(blueLocID[idx] + ' | ' + blueDelays[idx])
blueText
# Out:
# ['Stop ID: 8341 | Delay: -3831808',
#  'Stop ID: 8344 | Delay: -4123368',
#  'Stop ID: 8345 | Delay: -4577134',
#  'Stop ID: 8346 | Delay: -4986604',
#  'Stop ID: 8347 | Delay: -6747964']

# %%
gdelays = list(map(str, greenLine_top5['delay']))
greenDelays = ['Delay: ' + s for s in gdelays]
gLocID = list(map(str, greenLine_top5['lastLocID']))
greenLocID = ['Stop ID: ' + s for s in gLocID]

greenText = []
for idx in range(len(greenLocID)):
    greenText.append(greenLocID[idx] + ' | ' + greenDelays[idx])
greenText
# Out:
# ['Stop ID: 8341 | Delay: -2364557',
#  'Stop ID: 8344 | Delay: -2317606',
#  'Stop ID: 8345 | Delay: -2593475',
#  'Stop ID: 8346 | Delay: -2845667',
#  'Stop ID: 8347 | Delay: -3786845']

# %%
rdelays = list(map(str, redLine_top5['delay']))
redDelays = ['Delay: ' + s for s in rdelays]
rLocID = list(map(str, redLine_top5['lastLocID']))
redLocID = ['Stop ID: ' + s for s in rLocID]

redText = []
for idx in range(len(redLocID)):
    redText.append(redLocID[idx] + ' | ' + redDelays[idx])
redText
# Out:
# ['Stop ID: 8341 | Delay: -2309046',
#  'Stop ID: 8344 | Delay: -2162195',
#  'Stop ID: 8345 | Delay: -2419728',
#  'Stop ID: 8346 | Delay: -2638280',
#  'Stop ID: 8347 | Delay: -2696563']

# %%
# blue line
trace0 = go.Scattermapbox(
        name='Blue Line',
        lat=blueLine_top5['vehicle_location_latitude'],
        lon=blueLine_top5['vehicle_location_longitude'],
        mode='markers',
        marker=dict(
            size=12,
            color=lineColors['Blue']
        ),
        opacity=1,
        text=blueText
    )

# green line
trace1 = go.Scattermapbox(
        name='Green Line',
        lat=greenLine_top5['vehicle_location_latitude'],
        lon=greenLine_top5['vehicle_location_longitude'],
        mode='markers',
        marker=dict(
            size=12,
            color=lineColors['Green']
        ),
        opacity=1,
        text=greenText
    )

# red line
trace2 = go.Scattermapbox(
        name='Red Line',
        lat=redLine_top5['vehicle_location_latitude'],
        lon=redLine_top5['vehicle_location_longitude'],
        mode='markers',
        marker=dict(
            size=12,
            color=lineColors['Red']
        ),
        opacity=1,
        text=redText,
        hoverinfo='text'
    )

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=45.53,
            lon=-122.60
        ),
        pitch=0,
        zoom=10.5,
    ),
    margin=dict(l=0,
               r=0,
               t=30,
               b=50),
    legend=dict(font=dict(size=14),
               orientation='h',
               y=1.1)
    
)

fig = dict(data=[trace0, trace1, trace2], layout=layout)
plotly.offline.iplot(fig, filename='top5delays.html')
# Out:
# <div id="7a3473ce-6038-408c-8c7d-6276d6876092" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7a3473ce-6038-408c-8c7d-6276d6876092", [{"lat": [45.53008, 45.53248, 45.52931, 45.53282, 45.52966], "lon": [-122.66086, -122.62008, -122.60165, -122.57647, -122.56371], "marker": {"color": "rgba(0, 102, 204, 0.8)", "size": 12}, "mode": "markers", "name": "Blue Line", "opacity": 1, "text": ["Stop ID: 8341 | Delay: -3831808", "Stop ID: 8344 | Delay: -4123368", "Stop ID: 8345 | Delay: -4577134", "Stop ID: 8346 | Delay: -4986604", "Stop ID: 8347 | Delay: -6747964"], "type": "scattermapbox", "uid": "affb24ac-afac-11e8-bbaf-e442a6f8adc6"}, {"lat": [45.53004, 45.53267, 45.52941, 45.5328, 45.52955], "lon": [-122.66091, -122.61989, -122.60155, -122.57649, -122.56383], "marker": {"color": "rgba(51, 204, 51, 0.8)", "size": 12}, "mode": "markers", "name": "Green Line", "opacity": 1, "text": ["Stop ID: 8341 | Delay: -2364557", "Stop ID: 8344 | Delay: -2317606", "Stop ID: 8345 | Delay: -2593475", "Stop ID: 8346 | Delay: -2845667", "Stop ID: 8347 | Delay: -3786845"], "type": "scattermapbox", "uid": "affb24ad-afac-11e8-9efe-e442a6f8adc6"}, {"hoverinfo": "text", "lat": [45.53015, 45.53248, 45.52946, 45.53279, 45.52945], "lon": [-122.6608, -122.62008, -122.6015, -122.5765, -122.56392], "marker": {"color": "rgba(255, 0, 0, 0.8)", "size": 12}, "mode": "markers", "name": "Red Line", "opacity": 1, "text": ["Stop ID: 8341 | Delay: -2309046", "Stop ID: 8344 | Delay: -2162195", "Stop ID: 8345 | Delay: -2419728", "Stop ID: 8346 | Delay: -2638280", "Stop ID: 8347 | Delay: -2696563"], "type": "scattermapbox", "uid": "affb24ae-afac-11e8-8cb6-e442a6f8adc6"}], {"autosize": true, "hovermode": "closest", "legend": {"font": {"size": 14}, "orientation": "h", "y": 1.1}, "mapbox": {"accesstoken": "pk.eyJ1Ijoia2VubmZ1Y2l1cyIsImEiOiJjamp6Nnh4dHYxaTUwM3Bta3pobHFodWZqIn0.bRn1e3Cbc1v9PNQh_RsDwA", "bearing": 0, "center": {"lat": 45.53, "lon": -122.6}, "pitch": 0, "zoom": 10.5}, "margin": {"b": 50, "l": 0, "r": 0, "t": 30}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# The top 10 stop IDs with the longest delays are all on the east side of Portland. This is an interesting insight that warrants further investigation.

# %% [markdown]
# Finally, the last thing I want to do is plot a heatmap showing the mean delay for each stop.

# %%
delays = rail_clean[['lastLocID', 'delay']].groupby('lastLocID').mean().sort_values('delay')
delays[:10]
# Out:
#                  delay
# lastLocID
# 10119     -1000.000000
# 8350       -262.652274
# 8355       -259.552642
# 8351       -241.048450
# 13450      -232.429548
# 9836       -226.384004
# 8349       -224.042050
# 8354       -223.990069
# 8356       -220.875552
# 8352       -215.675615

# %%
stop_delays = delays.join(locations)
stop_delays[:10]
# Out:
#                  delay  vehicle_location_longitude  vehicle_location_latitude
# lastLocID
# 10119     -1000.000000                 -122.682669                  45.519415
# 8350       -262.652274                 -122.508260                  45.522260
# 8355       -259.552642                 -122.457514                  45.514905
# 8351       -241.048450                 -122.492529                  45.522129
# 13450      -232.429548                 -122.440305                  45.507583
# 9836       -226.384004                 -122.917075                  45.530318
# 8349       -224.042050                 -122.528556                  45.522418
# 8354       -223.990069                 -122.467001                  45.518934
# 8356       -220.875552                 -122.434206                  45.505023
# 8352       -215.675615                 -122.482430                  45.522041

# %% [markdown]
# The first locID (10119) is a clear outlier at an average of -1000 delay. This stop actually only has two entries in the entire data set and will be excluded.

# %%
stop_delays = (stop_delays.iloc[1:, :].reset_index()).round(5)
stop_delays[:10]
# Out:
#    lastLocID      delay  vehicle_location_longitude  vehicle_location_latitude
# 0       8350 -262.65227                  -122.50826                   45.52226
# 1       8355 -259.55264                  -122.45751                   45.51490
# 2       8351 -241.04845                  -122.49253                   45.52213
# 3      13450 -232.42955                  -122.44030                   45.50758
# 4       9836 -226.38400                  -122.91708                   45.53032
# 5       8349 -224.04205                  -122.52856                   45.52242
# 6       8354 -223.99007                  -122.46700                   45.51893
# 7       8356 -220.87555                  -122.43421                   45.50502
# 8       8352 -215.67561                  -122.48243                   45.52204
# 9       8353 -210.57422                  -122.47510                   45.52182

# %%
locID = list(map(str, stop_delays['lastLocID']))
locIDs = ['Stop ID: ' + s for s in locID]
delay = list(map(str, -stop_delays['delay']))
delays = ['Delay: ' + s for s in delay]

text = []
for idx in range(len(locIDs)):
    text.append(locIDs[idx] + '  |  ' + delays[idx])
text[:10]
# Out:
# ['Stop ID: 8350  |  Delay: 262.65227',
#  'Stop ID: 8355  |  Delay: 259.55264',
#  'Stop ID: 8351  |  Delay: 241.04845',
#  'Stop ID: 13450  |  Delay: 232.42955',
#  'Stop ID: 9836  |  Delay: 226.384',
#  'Stop ID: 8349  |  Delay: 224.04205',
#  'Stop ID: 8354  |  Delay: 223.99007',
#  'Stop ID: 8356  |  Delay: 220.87555',
#  'Stop ID: 8352  |  Delay: 215.67561',
#  'Stop ID: 8353  |  Delay: 210.57422']

# %%
trace0 = go.Scattermapbox(
        lat=blueLine_top5['vehicle_location_latitude'],
        lon=blueLine_top5['vehicle_location_longitude'],
        mode='markers',
        marker=dict(
            size=18,
            color='rgb(255, 0, 255)',
            colorscale='Portland',
            opacity=.7
        ),
        showlegend=False
    )

trace1 = go.Scattermapbox(
        lat=stop_delays['vehicle_location_latitude'],
        lon=stop_delays['vehicle_location_longitude'],
        mode='markers',
        marker=dict(
            size=9,
            color=-stop_delays['delay'],
            colorscale='Portland',
            showscale=True,
            opacity=1
        ),
        text=text,
        showlegend=False
    )

data=[trace0, trace1]

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=center_lat,
            lon=center_lon
        ),
        pitch=0,
        zoom=9,
    ),
    margin=dict(l=0,
               r=0,
               t=30,
               b=50)
    
)

fig = dict(data=data, layout=layout)
plotly.offline.iplot(fig, filename='TrimetDelayMap.html')
# Out:
# <div id="34da25a7-16d7-4794-9ef2-84dc2229bd19" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("34da25a7-16d7-4794-9ef2-84dc2229bd19", [{"lat": [45.53008, 45.53248, 45.52931, 45.53282, 45.52966], "lon": [-122.66086, -122.62008, -122.60165, -122.57647, -122.56371], "marker": {"color": "rgb(255, 0, 255)", "colorscale": "Portland", "opacity": 0.7, "size": 18}, "mode": "markers", "showlegend": false, "type": "scattermapbox", "uid": "b02bb66c-afac-11e8-a4e8-e442a6f8adc6"}, {"lat": [45.52226, 45.5149, 45.52213, 45.50758, 45.53032, 45.52242, 45.51893, 45.50502, 45.52204, 45.52182, 45.52258, 45.5203, 45.50214, 45.5244, 45.52957, 45.51086, 45.5061, 45.59869, 45.48887, 45.50119, 45.49518, 45.53085, 45.51849, 45.50246, 45.55001, 45.57948, 45.58441, 45.51086, 45.50195, 45.56092, 45.56572, 45.47283, 45.54045, 45.49443, 45.54912, 45.52118, 45.5564, 45.49097, 45.57261, 45.52874, 45.51854, 45.50644, 45.51896, 45.49649, 45.48919, 45.51049, 45.51922, 45.47937, 45.5096, 45.57829, 45.52633, 45.51891, 45.53278, 45.5194, 45.45967, 45.51964, 45.57252, 45.52282, 45.49086, 45.52129, 45.52795, 45.518, 45.52139, 45.51871, 45.52934, 45.52184, 45.50294, 45.52518, 45.45008, 45.52133, 45.52346, 45.51671, 45.53258, 45.53008, 45.5345, 45.53005, 45.52061, 45.52428, 45.43848, 45.46408, 45.53, 45.51026, 45.52991, 45.53007, 45.53008, 45.50663, 45.52972, 45.52629, 45.50002, 45.52571, 45.5278, 45.53169, 45.5128, 45.49379, 45.504, 45.53359, 45.50953, 45.53013, 45.508, 45.52171, 45.52971, 45.53017, 45.45664, 45.51635, 45.52162, 45.51789, 45.53009, 45.4774, 45.53011, 45.5227, 45.52412, 45.50941, 45.53827, 45.5088, 45.51747, 45.51895, 45.49381, 45.50971, 45.465, 45.44285, 45.51089, 45.55406, 45.50461, 45.50354, 45.51538, 45.4908, 45.57191, 45.47159, 45.52255, 45.52766, 45.49208, 45.51706, 45.59458, 45.51355, 45.49937, 45.51832, 45.5302, 45.5216, 45.51816, 45.57591, 45.50281, 45.48224, 45.50624, 45.58308, 45.52977, 45.53535, 45.52239, 45.51016, 45.52094, 45.50694, 45.57505, 45.52106, 45.54624, 45.58686, 45.52207, 45.43594, 45.50869, 45.56784, 45.60507, 45.52132, 45.52167, 45.56101, 45.50193, 45.43109, 45.5541, 45.52222, 45.52111, 45.52214, 45.52125, 45.50597, 45.49343, 45.53255, 45.4981], "lon": [-122.50826, -122.45751, -122.49253, -122.4403, -122.91708, -122.52856, -122.467, -122.43421, -122.48243, -122.4751, -122.55095, -122.68327, -122.42424, -122.89248, -122.56381, -122.56494, -122.84381, -122.68486, -122.64854, -122.56673, -122.64838, -122.66921, -122.87391, -122.65277, -122.56336, -122.56963, -122.68643, -122.85325, -122.836, -122.56317, -122.68217, -122.63956, -122.67701, -122.56605, -122.68098, -122.69072, -122.68227, -122.81066, -122.5615, -122.93725, -122.67667, -122.66115, -122.67824, -122.82454, -122.56648, -122.72386, -122.67857, -122.56697, -122.78212, -122.68207, -122.94954, -122.69672, -122.57651, -122.692, -122.63648, -122.68079, -122.68211, -122.67658, -122.80316, -122.97133, -122.67648, -122.67798, -122.98664, -122.67307, -122.60161, -122.67147, -122.67032, -122.67653, -122.57257, -122.98038, -122.67543, -122.67993, -122.61998, -122.66087, -122.5812, -122.65111, -122.67656, -122.67142, -122.64102, -122.56966, -122.66595, -122.68221, -122.66632, -122.65667, -122.66355, -122.66317, -122.6672, -122.67552, -122.64908, -122.67139, -122.6097, -122.56449, -122.68202, -122.6484, -122.65532, -122.62418, -122.85063, -122.66381, -122.68157, -122.88413, -122.56345, -122.91281, -122.5737, -122.86761, -122.67153, -122.6735, -122.65514, -122.64059, -122.65913, -122.55979, -122.67135, -122.77879, -122.67461, -122.68308, -122.67548, -122.68095, -122.81795, -122.44526, -122.63793, -122.63911, -122.71381, -122.56652, -122.67381, -122.83916, -122.56436, -122.80507, -122.55738, -122.56601, -122.54135, -122.94295, -122.7998, -122.46249, -122.68603, -122.68041, -122.8311, -122.69261, -122. ...

# %% [markdown]
# We can size the circles by the color

# %% [markdown]
# ## SUPPLEMENTAL

# %%
plotly.__version__
# Out:
# '3.1.0'
